# %% [markdown]
# # Deep MLP

# %% [markdown]
# # Preliminaries

# %% [markdown]
# Check for GPU

# %%
import tensorflow as tf

# %%
if tf.test.gpu_device_name() != '/device:GPU:0':
  print("No GPU found")
else:
  print("GPU ready: {}".format(tf.test.gpu_device_name()))

# %% [markdown]
# Import preprocessing helper functions

# %%
import sys
sys.path.append("../../helper-modules")
from preprocessing_utils import read_in_data, preprocess

# %% [markdown]
# Read in the data to df_train, df_val and df_test

# %%
df_train, df_val, df_test = read_in_data()

# %% [markdown]
# Create X_train, y_train, X_val, y_val, X_test, y_test

# %%
(X_train, y_train), (X_val, y_val), (X_test, y_test) = preprocess("MLP", df_train, df_test, df_val)

# %% [markdown]
# # Model Building

# %% [markdown]
# Imports

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from itertools import product
import time
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Enable seed setting for improved reproducibility

# %%
import os
import random
import numpy as np

# %%
def set_seed(seed=42):
  SEED=seed

  # 1. Set `PYTHONHASHSEED` environment variable at a fixed value
  os.environ['PYTHONHASHSEED']=str(SEED)

  # 2. Set `python` built-in pseudo-random generator at a fixed value
  random.seed(SEED)

  # 3. Set `numpy` pseudo-random generator at a fixed value
  np.random.seed(SEED)

  # 4. Set the `tensorflow` pseudo-random generator at a fixed value
  tf.random.set_seed(SEED)

# %% [markdown]
# Extract number of classes (10 classes)

# %%
NUM_CLASSES = df_test["label"].nunique()

# %% [markdown]
# Model design

# %%
def compile_model(hidden_layers_sizes=(1024,), act_function="relu", dropout_rate=0.1, l_rate=0.001, reg='l2', opt_algo='adam'):
    model = Sequential()

    # Add hidden layers with dropout to prevent overfitting
    for i, h in enumerate(hidden_layers_sizes):
      if i == 0:
        model.add(Dense(h, activation=act_function, input_shape=(1480,)))
      else: 
        model.add(Dense(h, activation=act_function))
      model.add(Dropout(dropout_rate))
    
    # LAST LAYER IS THE CLASSIFIER, THUS 12 POSSIBLE CLASSES
    model.add(Dense(NUM_CLASSES, activation='softmax', kernel_regularizer=reg))

    # Optimization algorithm
    if opt_algo == 'adam':
      opt = tf.keras.optimizers.Adam(learning_rate=l_rate)
    elif opt_algo == 'sgd':
      opt = tf.keras.optimizers.SGD(learning_rate=l_rate)

    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# # Experiment: Grid Search

# %% [markdown]
# Defining grid search hyperparameter options

# %%
hidden_layers_sizes = [(1, 1, 1), (5, 10, 10), (20, 50, 50), (70, 100, 100),
       (200, 350, 350), (450, 900, 900)]
l_rates = [0.01, 0.005, 0.001, 0.0005, 0.0001]
dropout_rates = [0.05, 0.1, 0.2, 0.5]
act_functions=["relu"]
regs = ['l2']
opt_algos = ['adam']

all_hparams = [hidden_layers_sizes, l_rates, dropout_rates, act_functions, regs, opt_algos]

# %% [markdown]
# Conduct the grid search

# %%
def grid_search():
  """
  For each `hidden_layers_sizes` option (corresponding to a given number of parameters), conduct a grid search
  over the hyperparameter options, writing the validation results and model details for each model to a file.
  
  All trained models are saved as h5 files. 
  """
 
  best_model = None
  best_accuracy = 0
  best_history = None

  EPOCHS = 50
  BATCH_SIZE = 32
  STOPPING_PATIENCE = 5

  STARTING_POINT = 1

  with open('../training-results/ExperimentLogs_Deep-MLP.csv', 'w') as log_file:
      log_file.write("ModelNumber;Timestamp;NumEpochs;ValAccuracy;NumParams;HiddenLayerSizes;LearningRate;DropoutRate;ActivationFunction;Regularization;OptimizationAlgorithm\n")

  for model_num, hparam_set in enumerate(list(product(*all_hparams))[106:], start=STARTING_POINT):
    # Extract hyperparams for current model from grid search grid
    hidden_layers_sizes_tup, l_rate, dropout_rate, act_function, reg, opt_algo = hparam_set

    # Define hyperparameters for the current model 
    hparams = {
        "hidden_layers_sizes" : hidden_layers_sizes_tup,
        "act_function" : act_function, 
        "dropout_rate" : dropout_rate, 
        "l_rate": l_rate,
        "reg" : reg,
        "opt_algo" : opt_algo
    }

    # Compile model and count number of parameters
    model = compile_model(**hparams)
    num_params = model.count_params()

    model_str = f"{hidden_layers_sizes_tup}; {l_rate}; {dropout_rate}; {act_function}; {reg}; {opt_algo}"
    print(f"Training model {model_num} with {num_params} params - {model_str}")

    # Prevent overfitting with early stopping
    early_stop = EarlyStopping(monitor='val_accuracy', patience=STOPPING_PATIENCE)
    # For saving best val accuracy model as an h5 (for test predictions later)
    model_check = ModelCheckpoint(f"/content/drive/My Drive/data/experiments/trained-models/Deep-MLP_{model_num}.h5", monitor='val_accuracy', mode='max', verbose=0, save_best_only=True)

    # Set seed for reproducibility
    set_seed(42)

    # Train model
    # Note: one reason val accuracy might be higher than train accuracy during training is because dropout affects training but not validation
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_val, y_val), callbacks=[early_stop, model_check])
    n_epochs = len(history.history['loss'])
                   
    # Time stamp when model finished training
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())

    # Extract best validation accuracy at inex 1 (index 0 has the loss)
    val_accuracy = max(history.history['val_accuracy'])
    print(f"Best val accuracy: {val_accuracy}")

    # Store results in log file
    with open('../training-results/ExperimentLogs_Deep-MLP.csv', 'a') as log_file:
      log_file.write(f"{model_num};{timestamp};{n_epochs};{val_accuracy};{num_params};{model_str}\n")

    if val_accuracy > best_accuracy:
      best_accuracy = val_accuracy
      best_model = model
      best_history = history

  # Return the model with the highest validation accuracy
  return best_model, best_history

# %%
best_model, best_history = grid_search()
# Out:
# Training model 107 with 1892260 params - (450, 900, 900); 0.005; 0.2; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.3727 - accuracy: 0.4602 - val_loss: 1.0918 - val_accuracy: 0.5205
# Epoch 2/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.2569 - accuracy: 0.4827 - val_loss: 1.1464 - val_accuracy: 0.5241
# Epoch 3/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 1.2168 - accuracy: 0.4991 - val_loss: 1.0880 - val_accuracy: 0.5611
# Epoch 4/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.1858 - accuracy: 0.5133 - val_loss: 1.1998 - val_accuracy: 0.5456
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.1673 - accuracy: 0.5183 - val_loss: 1.1372 - val_accuracy: 0.5177
# Epoch 6/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.1814 - accuracy: 0.5120 - val_loss: 1.0011 - val_accuracy: 0.5546
# Epoch 7/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.1599 - accuracy: 0.5139 - val_loss: 0.9998 - val_accuracy: 0.5747
# Epoch 8/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.1362 - accuracy: 0.5252 - val_loss: 1.0260 - val_accuracy: 0.5809
# Epoch 9/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.1211 - accuracy: 0.5318 - val_loss: 1.0209 - val_accuracy: 0.5627
# Epoch 10/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.1325 - accuracy: 0.5270 - val_loss: 0.9892 - val_accuracy: 0.5804
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.1224 - accuracy: 0.5319 - val_loss: 0.9652 - val_accuracy: 0.5878
# Epoch 12/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.1350 - accuracy: 0.5278 - val_loss: 1.0695 - val_accuracy: 0.5649
# Epoch 13/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.1276 - accuracy: 0.5274 - val_loss: 0.9500 - val_accuracy: 0.5749
# Epoch 14/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.1098 - accuracy: 0.5331 - val_loss: 1.0018 - val_accuracy: 0.5615
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0990 - accuracy: 0.5359 - val_loss: 1.0146 - val_accuracy: 0.5534
# Epoch 16/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 1.1505 - accuracy: 0.5185 - val_loss: 1.0125 - val_accuracy: 0.5854
# Best val accuracy: 0.5877500176429749
# Training model 108 with 1892260 params - (450, 900, 900); 0.005; 0.5; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 1.8834 - accuracy: 0.2947 - val_loss: 1.8183 - val_accuracy: 0.3078
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 1.8707 - accuracy: 0.2910 - val_loss: 1.8193 - val_accuracy: 0.3071
# Epoch 3/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8762 - accuracy: 0.2890 - val_loss: 1.8470 - val_accuracy: 0.3026
# Epoch 4/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 1.8690 - accuracy: 0.2910 - val_loss: 1.8126 - val_accuracy: 0.3113
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8764 - accuracy: 0.2902 - val_loss: 1.8303 - val_accuracy: 0.3060
# Epoch 6/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8609 - accuracy: 0.2901 - val_loss: 1.8077 - val_accuracy: 0.3124
# Epoch 7/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8650 - accuracy: 0.2914 - val_loss: 2.3974 - val_accuracy: 0.3167
# Epoch 8/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8582 - accuracy: 0.2879 - val_loss: 1.8098 - val_accuracy: 0.3041
# Epoch 9/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.8600 - accuracy: 0.2916 - val_loss: 1.8049 - val_accuracy: 0.3066
# Epoch 10/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 1.8661 - accuracy: 0.2896 - val_loss: 1.7945 - val_accuracy: 0.3054
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8632 - accuracy: 0.2891 - val_loss: 1.8103 - val_accuracy: 0.3086
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.8696 - accuracy: 0.2907 - val_loss: 1.8124 - val_accuracy: 0.3113
# Best val accuracy: 0.3166874945163727
# Training model 109 with 1892260 params - (450, 900, 900); 0.001; 0.05; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9700 - accuracy: 0.5959 - val_loss: 0.8583 - val_accuracy: 0.6440
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7922 - accuracy: 0.6509 - val_loss: 0.7878 - val_accuracy: 0.6646
# Epoch 3/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7326 - accuracy: 0.6718 - val_loss: 0.7454 - val_accuracy: 0.6762
# Epoch 4/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6899 - accuracy: 0.6892 - val_loss: 0.7143 - val_accuracy: 0.6877
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6567 - accuracy: 0.7001 - val_loss: 0.6831 - val_accuracy: 0.7039
# Epoch 6/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6298 - accuracy: 0.7128 - val_loss: 0.6867 - val_accuracy: 0.7015
# Epoch 7/50
# 2000/2000 [==============================] - 29s 15ms/step - loss: 0.6065 - accuracy: 0.7220 - val_loss: 0.7211 - val_accuracy: 0.6844
# Epoch 8/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5946 - accuracy: 0.7250 - val_loss: 0.6929 - val_accuracy: 0.7046
# Epoch 9/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5677 - accuracy: 0.7385 - val_loss: 0.7177 - val_accuracy: 0.7048
# Epoch 10/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5524 - accuracy: 0.7471 - val_loss: 0.6776 - val_accuracy: 0.7178
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5369 - accuracy: 0.7539 - val_loss: 0.6794 - val_accuracy: 0.7173
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5224 - accuracy: 0.7614 - val_loss: 0.6878 - val_accuracy: 0.7188
# Epoch 13/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5042 - accuracy: 0.7674 - val_loss: 0.7176 - val_accuracy: 0.7176
# Epoch 14/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4949 - accuracy: 0.7768 - val_loss: 0.6923 - val_accuracy: 0.7269
# Epoch 15/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4830 - accuracy: 0.7799 - val_loss: 0.6888 - val_accuracy: 0.7308
# Epoch 16/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4638 - accuracy: 0.7873 - val_loss: 0.7397 - val_accuracy: 0.7195
# Epoch 17/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4530 - accuracy: 0.7937 - val_loss: 0.6934 - val_accuracy: 0.7354
# Epoch 18/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4437 - accuracy: 0.7996 - val_loss: 0.7203 - val_accuracy: 0.7407
# Epoch 19/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4330 - accuracy: 0.8033 - val_loss: 0.7356 - val_accuracy: 0.7369
# Epoch 20/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4242 - accuracy: 0.8074 - val_loss: 0.7396 - val_accuracy: 0.7262
# Epoch 21/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4145 - accuracy: 0.8153 - val_loss: 0.7146 - val_accuracy: 0.7502
# Epoch 22/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4088 - accuracy: 0.8180 - val_loss: 0.7304 - val_accuracy: 0.7427
# Epoch 23/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3961 - accuracy: 0.8221 - val_loss: 0.7560 - val_accuracy: 0.7375
# Epoch 24/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3929 - accuracy: 0.8246 - val_loss: 0.7620 - val_accuracy: 0.7454
# Epoch 25/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3834 - accuracy: 0.8295 - val_loss: 0.7525 - val_accuracy: 0.7477
# Epoch 26/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3750 - accuracy: 0.8340 - val_loss: 0.8082 - val_accuracy: 0.7539
# Epoch 27/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3699 - accuracy: 0.8379 - val_loss: 0.7887 - val_accuracy: 0.7429
# Epoch 28/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.3590 - accuracy: 0.8429 - val_loss: 0.7944 - val_accuracy: 0.7616
# Epoch 29/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3558 - accuracy: 0.8434 - val_loss: 0.7731 - val_accuracy: 0.7499
# Epoch 30/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3570 - accuracy: 0.8436 - val_loss: 0.7658 - val_accuracy: 0.7605
# Epoch 31/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3442 - accuracy: 0.8503 - val_loss: 0.8662 - val_accuracy: 0.7421
# Epoch 32/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3361 - accuracy: 0.8544 - val_loss: 0.7802 - val_accuracy: 0.7575
# Epoch 33/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3308 - accuracy: 0.8557 - val_loss: 0.7804 - val_accuracy: 0.7606
# Best val accuracy: 0.7615625262260437
# Training model 110 with 1892260 params - (450, 900, 900); 0.001; 0.1; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9754 - accuracy: 0.5959 - val_loss: 0.8280 - val_accuracy: 0.6467
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.8045 - accuracy: 0.6483 - val_loss: 0.7806 - val_accuracy: 0.6623
# Epoch 3/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7459 - accuracy: 0.6689 - val_loss: 0.7427 - val_accuracy: 0.6777
# Epoch 4/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7069 - accuracy: 0.6823 - val_loss: 0.6983 - val_accuracy: 0.6871
# Epoch 5/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6791 - accuracy: 0.6924 - val_loss: 0.6951 - val_accuracy: 0.6942
# Epoch 6/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6511 - accuracy: 0.7017 - val_loss: 0.6899 - val_accuracy: 0.7016
# Epoch 7/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6265 - accuracy: 0.7118 - val_loss: 0.7205 - val_accuracy: 0.6913
# Epoch 8/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6138 - accuracy: 0.7175 - val_loss: 0.6686 - val_accuracy: 0.7114
# Epoch 9/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6007 - accuracy: 0.7212 - val_loss: 0.6778 - val_accuracy: 0.7014
# Epoch 10/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5897 - accuracy: 0.7255 - val_loss: 0.6681 - val_accuracy: 0.7105
# Epoch 11/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.5726 - accuracy: 0.7358 - val_loss: 0.6691 - val_accuracy: 0.7144
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5594 - accuracy: 0.7395 - val_loss: 0.6775 - val_accuracy: 0.7019
# Epoch 13/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5490 - accuracy: 0.7433 - val_loss: 0.6858 - val_accuracy: 0.7149
# Epoch 14/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5380 - accuracy: 0.7490 - val_loss: 0.6834 - val_accuracy: 0.7137
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5269 - accuracy: 0.7547 - val_loss: 0.6741 - val_accuracy: 0.7160
# Epoch 16/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5147 - accuracy: 0.7600 - val_loss: 0.6752 - val_accuracy: 0.7221
# Epoch 17/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5048 - accuracy: 0.7650 - val_loss: 0.7206 - val_accuracy: 0.7118
# Epoch 18/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4961 - accuracy: 0.7701 - val_loss: 0.7212 - val_accuracy: 0.7190
# Epoch 19/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4867 - accuracy: 0.7733 - val_loss: 0.7254 - val_accuracy: 0.7258
# Epoch 20/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4761 - accuracy: 0.7792 - val_loss: 0.6958 - val_accuracy: 0.7244
# Epoch 21/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.4633 - accuracy: 0.7848 - val_loss: 0.7031 - val_accuracy: 0.7413
# Epoch 22/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.4627 - accuracy: 0.7891 - val_loss: 0.7306 - val_accuracy: 0.7286
# Epoch 23/50
# 2000/2000 [==============================] - 33s 17ms/step - loss: 0.4496 - accuracy: 0.7940 - val_loss: 0.7802 - val_accuracy: 0.7089
# Epoch 24/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.4411 - accuracy: 0.7975 - val_loss: 0.7247 - val_accuracy: 0.7317
# Epoch 25/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4391 - accuracy: 0.7993 - val_loss: 0.7395 - val_accuracy: 0.7259
# Epoch 26/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4305 - accuracy: 0.8035 - val_loss: 0.7362 - val_accuracy: 0.7420
# Epoch 27/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4204 - accuracy: 0.8090 - val_loss: 0.7341 - val_accuracy: 0.7324
# Epoch 28/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4152 - accuracy: 0.8114 - val_loss: 0.7932 - val_accuracy: 0.7304
# Epoch 29/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4101 - accuracy: 0.8156 - val_loss: 0.7532 - val_accuracy: 0.7302
# Epoch 30/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4108 - accuracy: 0.8140 - val_loss: 0.7804 - val_accuracy: 0.7331
# Epoch 31/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.3984 - accuracy: 0.8213 - val_loss: 0.7472 - val_accuracy: 0.7415
# Best val accuracy: 0.7419999837875366
# Training model 111 with 1892260 params - (450, 900, 900); 0.001; 0.2; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0301 - accuracy: 0.5761 - val_loss: 0.8588 - val_accuracy: 0.6238
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.8561 - accuracy: 0.6312 - val_loss: 0.8314 - val_accuracy: 0.6483
# Epoch 3/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.8077 - accuracy: 0.6490 - val_loss: 0.8193 - val_accuracy: 0.6634
# Epoch 4/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7804 - accuracy: 0.6581 - val_loss: 0.7716 - val_accuracy: 0.6705
# Epoch 5/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7443 - accuracy: 0.6676 - val_loss: 0.7373 - val_accuracy: 0.6760
# Epoch 6/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7221 - accuracy: 0.6751 - val_loss: 0.7230 - val_accuracy: 0.6783
# Epoch 7/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7023 - accuracy: 0.6810 - val_loss: 0.7000 - val_accuracy: 0.6891
# Epoch 8/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6901 - accuracy: 0.6847 - val_loss: 0.7063 - val_accuracy: 0.6879
# Epoch 9/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6707 - accuracy: 0.6935 - val_loss: 0.6978 - val_accuracy: 0.6929
# Epoch 10/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6602 - accuracy: 0.6977 - val_loss: 0.6921 - val_accuracy: 0.6968
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6499 - accuracy: 0.7026 - val_loss: 0.7013 - val_accuracy: 0.6942
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6377 - accuracy: 0.7067 - val_loss: 0.6926 - val_accuracy: 0.6927
# Epoch 13/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6374 - accuracy: 0.7073 - val_loss: 0.6842 - val_accuracy: 0.7006
# Epoch 14/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6312 - accuracy: 0.7078 - val_loss: 0.7000 - val_accuracy: 0.6994
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6203 - accuracy: 0.7147 - val_loss: 0.6716 - val_accuracy: 0.7078
# Epoch 16/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6117 - accuracy: 0.7170 - val_loss: 0.7024 - val_accuracy: 0.7001
# Epoch 17/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5981 - accuracy: 0.7221 - val_loss: 0.7111 - val_accuracy: 0.6969
# Epoch 18/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5980 - accuracy: 0.7223 - val_loss: 0.7053 - val_accuracy: 0.6941
# Epoch 19/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5926 - accuracy: 0.7258 - val_loss: 0.6938 - val_accuracy: 0.7094
# Epoch 20/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5899 - accuracy: 0.7254 - val_loss: 0.6990 - val_accuracy: 0.7082
# Epoch 21/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5774 - accuracy: 0.7320 - val_loss: 0.7052 - val_accuracy: 0.6966
# Epoch 22/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5725 - accuracy: 0.7340 - val_loss: 0.6870 - val_accuracy: 0.7033
# Epoch 23/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5729 - accuracy: 0.7359 - val_loss: 0.7143 - val_accuracy: 0.6969
# Epoch 24/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5706 - accuracy: 0.7336 - val_loss: 0.7431 - val_accuracy: 0.6886
# Best val accuracy: 0.7094374895095825
# Training model 112 with 1892260 params - (450, 900, 900); 0.001; 0.5; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.3196 - accuracy: 0.4757 - val_loss: 1.0313 - val_accuracy: 0.5717
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 1.0896 - accuracy: 0.5437 - val_loss: 1.0111 - val_accuracy: 0.5723
# Epoch 3/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0255 - accuracy: 0.5680 - val_loss: 0.9804 - val_accuracy: 0.5884
# Epoch 4/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0386 - accuracy: 0.5695 - val_loss: 0.9407 - val_accuracy: 0.6264
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0270 - accuracy: 0.5700 - val_loss: 0.9010 - val_accuracy: 0.6262
# Epoch 6/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0119 - accuracy: 0.5775 - val_loss: 0.9450 - val_accuracy: 0.6080
# Epoch 7/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.9969 - accuracy: 0.5852 - val_loss: 0.8891 - val_accuracy: 0.6478
# Epoch 8/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.9650 - accuracy: 0.5954 - val_loss: 0.9131 - val_accuracy: 0.6108
# Epoch 9/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.9481 - accuracy: 0.5992 - val_loss: 0.9605 - val_accuracy: 0.6069
# Epoch 10/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.9414 - accuracy: 0.6010 - val_loss: 0.9235 - val_accuracy: 0.6125
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9331 - accuracy: 0.6053 - val_loss: 0.8661 - val_accuracy: 0.6224
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9360 - accuracy: 0.6050 - val_loss: 0.9932 - val_accuracy: 0.6059
# Best val accuracy: 0.6478124856948853
# Training model 113 with 1892260 params - (450, 900, 900); 0.0005; 0.05; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9770 - accuracy: 0.6036 - val_loss: 0.8075 - val_accuracy: 0.6528
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7760 - accuracy: 0.6594 - val_loss: 0.7631 - val_accuracy: 0.6740
# Epoch 3/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7107 - accuracy: 0.6824 - val_loss: 0.7209 - val_accuracy: 0.6938
# Epoch 4/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6631 - accuracy: 0.7032 - val_loss: 0.7013 - val_accuracy: 0.6891
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6261 - accuracy: 0.7179 - val_loss: 0.6949 - val_accuracy: 0.6950
# Epoch 6/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5972 - accuracy: 0.7287 - val_loss: 0.6699 - val_accuracy: 0.7072
# Epoch 7/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5676 - accuracy: 0.7438 - val_loss: 0.6912 - val_accuracy: 0.7059
# Epoch 8/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.5495 - accuracy: 0.7523 - val_loss: 0.6585 - val_accuracy: 0.7272
# Epoch 9/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.5197 - accuracy: 0.7666 - val_loss: 0.7027 - val_accuracy: 0.7116
# Epoch 10/50
# 2000/2000 [==============================] - 33s 17ms/step - loss: 0.5029 - accuracy: 0.7743 - val_loss: 0.6735 - val_accuracy: 0.7399
# Epoch 11/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4781 - accuracy: 0.7890 - val_loss: 0.6549 - val_accuracy: 0.7357
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4637 - accuracy: 0.7935 - val_loss: 0.6658 - val_accuracy: 0.7389
# Epoch 13/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4381 - accuracy: 0.8048 - val_loss: 0.7401 - val_accuracy: 0.7222
# Epoch 14/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4233 - accuracy: 0.8111 - val_loss: 0.7012 - val_accuracy: 0.7339
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4125 - accuracy: 0.8183 - val_loss: 0.7158 - val_accuracy: 0.7308
# Best val accuracy: 0.7398750185966492
# Training model 114 with 1892260 params - (450, 900, 900); 0.0005; 0.1; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9916 - accuracy: 0.5979 - val_loss: 0.8170 - val_accuracy: 0.6532
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7847 - accuracy: 0.6567 - val_loss: 0.7739 - val_accuracy: 0.6614
# Epoch 3/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7226 - accuracy: 0.6779 - val_loss: 0.7499 - val_accuracy: 0.6790
# Epoch 4/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6791 - accuracy: 0.6960 - val_loss: 0.7006 - val_accuracy: 0.6920
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6454 - accuracy: 0.7083 - val_loss: 0.6804 - val_accuracy: 0.7024
# Epoch 6/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6173 - accuracy: 0.7196 - val_loss: 0.6831 - val_accuracy: 0.6969
# Epoch 7/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5898 - accuracy: 0.7309 - val_loss: 0.6886 - val_accuracy: 0.7040
# Epoch 8/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5738 - accuracy: 0.7382 - val_loss: 0.6661 - val_accuracy: 0.7135
# Epoch 9/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5501 - accuracy: 0.7491 - val_loss: 0.6693 - val_accuracy: 0.7239
# Epoch 10/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5309 - accuracy: 0.7584 - val_loss: 0.6803 - val_accuracy: 0.7221
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5106 - accuracy: 0.7671 - val_loss: 0.6564 - val_accuracy: 0.7347
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4975 - accuracy: 0.7734 - val_loss: 0.7127 - val_accuracy: 0.7312
# Epoch 13/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4778 - accuracy: 0.7832 - val_loss: 0.7142 - val_accuracy: 0.7232
# Epoch 14/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4667 - accuracy: 0.7887 - val_loss: 0.7358 - val_accuracy: 0.7176
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4522 - accuracy: 0.7982 - val_loss: 0.6848 - val_accuracy: 0.7324
# Epoch 16/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4332 - accuracy: 0.8048 - val_loss: 0.6785 - val_accuracy: 0.7322
# Best val accuracy: 0.7346875071525574
# Training model 115 with 1892260 params - (450, 900, 900); 0.0005; 0.2; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.0324 - accuracy: 0.5842 - val_loss: 0.8296 - val_accuracy: 0.6504
# Epoch 2/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.8127 - accuracy: 0.6468 - val_loss: 0.7928 - val_accuracy: 0.6620
# Epoch 3/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7541 - accuracy: 0.6674 - val_loss: 0.7538 - val_accuracy: 0.6700
# Epoch 4/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7141 - accuracy: 0.6820 - val_loss: 0.7338 - val_accuracy: 0.6802
# Epoch 5/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6804 - accuracy: 0.6927 - val_loss: 0.7075 - val_accuracy: 0.6824
# Epoch 6/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6498 - accuracy: 0.7035 - val_loss: 0.6899 - val_accuracy: 0.7007
# Epoch 7/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6325 - accuracy: 0.7098 - val_loss: 0.6982 - val_accuracy: 0.6966
# Epoch 8/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6173 - accuracy: 0.7161 - val_loss: 0.6733 - val_accuracy: 0.7125
# Epoch 9/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5984 - accuracy: 0.7234 - val_loss: 0.6767 - val_accuracy: 0.7103
# Epoch 10/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5843 - accuracy: 0.7297 - val_loss: 0.6594 - val_accuracy: 0.7128
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5693 - accuracy: 0.7373 - val_loss: 0.6681 - val_accuracy: 0.7172
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5556 - accuracy: 0.7437 - val_loss: 0.6661 - val_accuracy: 0.7114
# Epoch 13/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5464 - accuracy: 0.7470 - val_loss: 0.7151 - val_accuracy: 0.7019
# Epoch 14/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5306 - accuracy: 0.7532 - val_loss: 0.6532 - val_accuracy: 0.7237
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5237 - accuracy: 0.7565 - val_loss: 0.6829 - val_accuracy: 0.7204
# Epoch 16/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.5116 - accuracy: 0.7621 - val_loss: 0.6719 - val_accuracy: 0.7164
# Epoch 17/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5016 - accuracy: 0.7675 - val_loss: 0.6572 - val_accuracy: 0.7244
# Epoch 18/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.4942 - accuracy: 0.7717 - val_loss: 0.6571 - val_accuracy: 0.7297
# Epoch 19/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.4809 - accuracy: 0.7751 - val_loss: 0.6787 - val_accuracy: 0.7309
# Epoch 20/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.4757 - accuracy: 0.7797 - val_loss: 0.6801 - val_accuracy: 0.7303
# Epoch 21/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4659 - accuracy: 0.7854 - val_loss: 0.6651 - val_accuracy: 0.7410
# Epoch 22/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4539 - accuracy: 0.7912 - val_loss: 0.7309 - val_accuracy: 0.7192
# Epoch 23/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4505 - accuracy: 0.7930 - val_loss: 0.7094 - val_accuracy: 0.7284
# Epoch 24/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4425 - accuracy: 0.7975 - val_loss: 0.7010 - val_accuracy: 0.7369
# Epoch 25/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4389 - accuracy: 0.7980 - val_loss: 0.7110 - val_accuracy: 0.7215
# Epoch 26/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.4253 - accuracy: 0.8039 - val_loss: 0.7040 - val_accuracy: 0.7402
# Best val accuracy: 0.7409999966621399
# Training model 116 with 1892260 params - (450, 900, 900); 0.0005; 0.5; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 1.2637 - accuracy: 0.5097 - val_loss: 0.9253 - val_accuracy: 0.6056
# Epoch 2/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.9674 - accuracy: 0.5895 - val_loss: 0.9009 - val_accuracy: 0.6279
# Epoch 3/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.9054 - accuracy: 0.6117 - val_loss: 0.8529 - val_accuracy: 0.6459
# Epoch 4/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.8651 - accuracy: 0.6269 - val_loss: 0.8187 - val_accuracy: 0.6598
# Epoch 5/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.8438 - accuracy: 0.6339 - val_loss: 0.8015 - val_accuracy: 0.6488
# Epoch 6/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.8197 - accuracy: 0.6438 - val_loss: 0.7939 - val_accuracy: 0.6676
# Epoch 7/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.8049 - accuracy: 0.6454 - val_loss: 0.7819 - val_accuracy: 0.6685
# Epoch 8/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7861 - accuracy: 0.6497 - val_loss: 0.7757 - val_accuracy: 0.6676
# Epoch 9/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7739 - accuracy: 0.6529 - val_loss: 0.7814 - val_accuracy: 0.6779
# Epoch 10/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7614 - accuracy: 0.6573 - val_loss: 0.7627 - val_accuracy: 0.6774
# Epoch 11/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7521 - accuracy: 0.6648 - val_loss: 0.7609 - val_accuracy: 0.6621
# Epoch 12/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7444 - accuracy: 0.6647 - val_loss: 0.7756 - val_accuracy: 0.6687
# Epoch 13/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7391 - accuracy: 0.6649 - val_loss: 0.7546 - val_accuracy: 0.6839
# Epoch 14/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7239 - accuracy: 0.6693 - val_loss: 0.7568 - val_accuracy: 0.6762
# Epoch 15/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7245 - accuracy: 0.6699 - val_loss: 0.7462 - val_accuracy: 0.6816
# Epoch 16/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.7180 - accuracy: 0.6743 - val_loss: 0.7362 - val_accuracy: 0.6861
# Epoch 17/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.7041 - accuracy: 0.6770 - val_loss: 0.7601 - val_accuracy: 0.6793
# Epoch 18/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7043 - accuracy: 0.6783 - val_loss: 0.7717 - val_accuracy: 0.6646
# Epoch 19/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6939 - accuracy: 0.6840 - val_loss: 0.7296 - val_accuracy: 0.6860
# Epoch 20/50
# 2000/2000 [==============================] - 33s 17ms/step - loss: 0.6902 - accuracy: 0.6836 - val_loss: 0.7215 - val_accuracy: 0.6864
# Epoch 21/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6839 - accuracy: 0.6882 - val_loss: 0.7810 - val_accuracy: 0.6689
# Epoch 22/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6815 - accuracy: 0.6885 - val_loss: 0.7222 - val_accuracy: 0.6746
# Epoch 23/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6751 - accuracy: 0.6872 - val_loss: 0.7234 - val_accuracy: 0.6888
# Epoch 24/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6708 - accuracy: 0.6902 - val_loss: 0.7462 - val_accuracy: 0.6813
# Epoch 25/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6652 - accuracy: 0.6928 - val_loss: 0.7356 - val_accuracy: 0.6826
# Epoch 26/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6647 - accuracy: 0.6937 - val_loss: 0.7222 - val_accuracy: 0.6924
# Epoch 27/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6588 - accuracy: 0.6960 - val_loss: 0.7034 - val_accuracy: 0.6957
# Epoch 28/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6606 - accuracy: 0.6948 - val_loss: 0.7128 - val_accuracy: 0.6886
# Epoch 29/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6555 - accuracy: 0.6962 - val_loss: 0.7141 - val_accuracy: 0.6908
# Epoch 30/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6479 - accuracy: 0.6976 - val_loss: 0.7005 - val_accuracy: 0.6963
# Epoch 31/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6554 - accuracy: 0.6986 - val_loss: 0.7297 - val_accuracy: 0.6921
# Epoch 32/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6461 - accuracy: 0.7009 - val_loss: 0.7229 - val_accuracy: 0.6893
# Epoch 33/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6432 - accuracy: 0.7020 - val_loss: 0.7425 - val_accuracy: 0.6883
# Epoch 34/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6377 - accuracy: 0.7051 - val_loss: 0.7599 - val_accuracy: 0.6817
# Epoch 35/50
# 2000/2000 [==============================] - 30s 15ms/step - loss: 0.6364 - accuracy: 0.7057 - val_loss: 0.7490 - val_accuracy: 0.6777
# Best val accuracy: 0.6962500214576721
# Training model 117 with 1892260 params - (450, 900, 900); 0.0001; 0.05; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 1.1349 - accuracy: 0.5819 - val_loss: 0.9144 - val_accuracy: 0.6451
# Epoch 2/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.8558 - accuracy: 0.6560 - val_loss: 0.8498 - val_accuracy: 0.6674
# Epoch 3/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7662 - accuracy: 0.6843 - val_loss: 0.8003 - val_accuracy: 0.6751
# Epoch 4/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7058 - accuracy: 0.7070 - val_loss: 0.7753 - val_accuracy: 0.6824
# Epoch 5/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6562 - accuracy: 0.7277 - val_loss: 0.7496 - val_accuracy: 0.6906
# Epoch 6/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6180 - accuracy: 0.7410 - val_loss: 0.7308 - val_accuracy: 0.6991
# Epoch 7/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5820 - accuracy: 0.7567 - val_loss: 0.7669 - val_accuracy: 0.6888
# Epoch 8/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5504 - accuracy: 0.7711 - val_loss: 0.7647 - val_accuracy: 0.6884
# Epoch 9/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5185 - accuracy: 0.7872 - val_loss: 0.7628 - val_accuracy: 0.6916
# Epoch 10/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4899 - accuracy: 0.7997 - val_loss: 0.7485 - val_accuracy: 0.7019
# Epoch 11/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4583 - accuracy: 0.8131 - val_loss: 0.7820 - val_accuracy: 0.6917
# Epoch 12/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4271 - accuracy: 0.8288 - val_loss: 0.7664 - val_accuracy: 0.7013
# Epoch 13/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.3969 - accuracy: 0.8438 - val_loss: 0.8227 - val_accuracy: 0.7045
# Epoch 14/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.3640 - accuracy: 0.8590 - val_loss: 0.8406 - val_accuracy: 0.7031
# Epoch 15/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.3366 - accuracy: 0.8734 - val_loss: 0.8680 - val_accuracy: 0.7054
# Epoch 16/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2966 - accuracy: 0.8918 - val_loss: 0.9101 - val_accuracy: 0.7080
# Epoch 17/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.2705 - accuracy: 0.9047 - val_loss: 0.9960 - val_accuracy: 0.7024
# Epoch 18/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2353 - accuracy: 0.9203 - val_loss: 1.0305 - val_accuracy: 0.7090
# Epoch 19/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.2126 - accuracy: 0.9290 - val_loss: 1.0534 - val_accuracy: 0.6996
# Epoch 20/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.1840 - accuracy: 0.9418 - val_loss: 1.1833 - val_accuracy: 0.6936
# Epoch 21/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.1623 - accuracy: 0.9501 - val_loss: 1.1708 - val_accuracy: 0.7038
# Epoch 22/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.1511 - accuracy: 0.9544 - val_loss: 1.2670 - val_accuracy: 0.6973
# Epoch 23/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.1396 - accuracy: 0.9590 - val_loss: 1.1888 - val_accuracy: 0.7031
# Best val accuracy: 0.7089999914169312
# Training model 118 with 1892260 params - (450, 900, 900); 0.0001; 0.1; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 1.1648 - accuracy: 0.5718 - val_loss: 0.9319 - val_accuracy: 0.6381
# Epoch 2/50
# 2000/2000 [==============================] - 33s 17ms/step - loss: 0.8726 - accuracy: 0.6497 - val_loss: 0.8604 - val_accuracy: 0.6614
# Epoch 3/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7837 - accuracy: 0.6757 - val_loss: 0.8033 - val_accuracy: 0.6766
# Epoch 4/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7238 - accuracy: 0.6983 - val_loss: 0.8013 - val_accuracy: 0.6699
# Epoch 5/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6751 - accuracy: 0.7165 - val_loss: 0.7525 - val_accuracy: 0.6864
# Epoch 6/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6370 - accuracy: 0.7296 - val_loss: 0.7214 - val_accuracy: 0.6994
# Epoch 7/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6011 - accuracy: 0.7470 - val_loss: 0.7523 - val_accuracy: 0.6878
# Epoch 8/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5716 - accuracy: 0.7591 - val_loss: 0.7558 - val_accuracy: 0.6842
# Epoch 9/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5401 - accuracy: 0.7739 - val_loss: 0.7381 - val_accuracy: 0.6904
# Epoch 10/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.5151 - accuracy: 0.7855 - val_loss: 0.7338 - val_accuracy: 0.7046
# Epoch 11/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4855 - accuracy: 0.7986 - val_loss: 0.7529 - val_accuracy: 0.6961
# Epoch 12/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4588 - accuracy: 0.8105 - val_loss: 0.7590 - val_accuracy: 0.7039
# Epoch 13/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.4336 - accuracy: 0.8236 - val_loss: 0.8050 - val_accuracy: 0.6998
# Epoch 14/50
# 2000/2000 [==============================] - 33s 17ms/step - loss: 0.4066 - accuracy: 0.8370 - val_loss: 0.8117 - val_accuracy: 0.7041
# Epoch 15/50
# 2000/2000 [==============================] - 34s 17ms/step - loss: 0.3811 - accuracy: 0.8499 - val_loss: 0.8295 - val_accuracy: 0.7083
# Epoch 16/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.3507 - accuracy: 0.8645 - val_loss: 0.8743 - val_accuracy: 0.7012
# Epoch 17/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.3240 - accuracy: 0.8756 - val_loss: 0.9135 - val_accuracy: 0.7059
# Epoch 18/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2960 - accuracy: 0.8901 - val_loss: 0.9306 - val_accuracy: 0.7078
# Epoch 19/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2712 - accuracy: 0.9009 - val_loss: 1.0022 - val_accuracy: 0.6967
# Epoch 20/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.2448 - accuracy: 0.9144 - val_loss: 1.0268 - val_accuracy: 0.6978
# Best val accuracy: 0.7083125114440918
# Training model 119 with 1892260 params - (450, 900, 900); 0.0001; 0.2; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 1.2288 - accuracy: 0.5521 - val_loss: 0.9436 - val_accuracy: 0.6384
# Epoch 2/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.9065 - accuracy: 0.6376 - val_loss: 0.8607 - val_accuracy: 0.6534
# Epoch 3/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.8162 - accuracy: 0.6598 - val_loss: 0.8084 - val_accuracy: 0.6729
# Epoch 4/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.7596 - accuracy: 0.6791 - val_loss: 0.7992 - val_accuracy: 0.6713
# Epoch 5/50
# 2000/2000 [==============================] - 34s 17ms/step - loss: 0.7100 - accuracy: 0.7000 - val_loss: 0.7488 - val_accuracy: 0.6844
# Epoch 6/50
# 2000/2000 [==============================] - 34s 17ms/step - loss: 0.6751 - accuracy: 0.7107 - val_loss: 0.7266 - val_accuracy: 0.6968
# Epoch 7/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6413 - accuracy: 0.7252 - val_loss: 0.7470 - val_accuracy: 0.6837
# Epoch 8/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.6162 - accuracy: 0.7359 - val_loss: 0.7454 - val_accuracy: 0.6896
# Epoch 9/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5855 - accuracy: 0.7497 - val_loss: 0.7349 - val_accuracy: 0.6929
# Epoch 10/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5631 - accuracy: 0.7603 - val_loss: 0.7128 - val_accuracy: 0.7038
# Epoch 11/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5377 - accuracy: 0.7710 - val_loss: 0.7142 - val_accuracy: 0.7036
# Epoch 12/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.5157 - accuracy: 0.7799 - val_loss: 0.7214 - val_accuracy: 0.7044
# Epoch 13/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4941 - accuracy: 0.7913 - val_loss: 0.7511 - val_accuracy: 0.7040
# Epoch 14/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.4742 - accuracy: 0.8012 - val_loss: 0.7366 - val_accuracy: 0.7064
# Epoch 15/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.4544 - accuracy: 0.8118 - val_loss: 0.7723 - val_accuracy: 0.7074
# Epoch 16/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.4299 - accuracy: 0.8217 - val_loss: 0.7730 - val_accuracy: 0.7061
# Epoch 17/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.4101 - accuracy: 0.8323 - val_loss: 0.8380 - val_accuracy: 0.6960
# Epoch 18/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.3916 - accuracy: 0.8421 - val_loss: 0.8060 - val_accuracy: 0.7086
# Epoch 19/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.3687 - accuracy: 0.8539 - val_loss: 0.8274 - val_accuracy: 0.7074
# Epoch 20/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.3480 - accuracy: 0.8635 - val_loss: 0.8612 - val_accuracy: 0.7021
# Epoch 21/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.3256 - accuracy: 0.8748 - val_loss: 0.8996 - val_accuracy: 0.7076
# Epoch 22/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.3112 - accuracy: 0.8817 - val_loss: 0.9053 - val_accuracy: 0.7111
# Epoch 23/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2868 - accuracy: 0.8924 - val_loss: 0.9651 - val_accuracy: 0.6972
# Epoch 24/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.2715 - accuracy: 0.8988 - val_loss: 0.9595 - val_accuracy: 0.6992
# Epoch 25/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.2512 - accuracy: 0.9093 - val_loss: 0.9458 - val_accuracy: 0.7050
# Epoch 26/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.2338 - accuracy: 0.9167 - val_loss: 1.0356 - val_accuracy: 0.7077
# Epoch 27/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.2188 - accuracy: 0.9233 - val_loss: 1.0043 - val_accuracy: 0.7050
# Best val accuracy: 0.7111250162124634
# Training model 120 with 1892260 params - (450, 900, 900); 0.0001; 0.5; relu; l2; adam
# Epoch 1/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 1.5502 - accuracy: 0.4518 - val_loss: 1.0381 - val_accuracy: 0.6068
# Epoch 2/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 1.0551 - accuracy: 0.5889 - val_loss: 0.9373 - val_accuracy: 0.6295
# Epoch 3/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.9457 - accuracy: 0.6137 - val_loss: 0.8713 - val_accuracy: 0.6436
# Epoch 4/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.8846 - accuracy: 0.6305 - val_loss: 0.8450 - val_accuracy: 0.6507
# Epoch 5/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.8423 - accuracy: 0.6419 - val_loss: 0.8115 - val_accuracy: 0.6537
# Epoch 6/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.8075 - accuracy: 0.6509 - val_loss: 0.7869 - val_accuracy: 0.6633
# Epoch 7/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7791 - accuracy: 0.6630 - val_loss: 0.7689 - val_accuracy: 0.6679
# Epoch 8/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7561 - accuracy: 0.6684 - val_loss: 0.7522 - val_accuracy: 0.6652
# Epoch 9/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7338 - accuracy: 0.6752 - val_loss: 0.7368 - val_accuracy: 0.6793
# Epoch 10/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.7140 - accuracy: 0.6835 - val_loss: 0.7291 - val_accuracy: 0.6884
# Epoch 11/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.7003 - accuracy: 0.6883 - val_loss: 0.7263 - val_accuracy: 0.6862
# Epoch 12/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6802 - accuracy: 0.6954 - val_loss: 0.7137 - val_accuracy: 0.6837
# Epoch 13/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6669 - accuracy: 0.7011 - val_loss: 0.7283 - val_accuracy: 0.6787
# Epoch 14/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6576 - accuracy: 0.7038 - val_loss: 0.7031 - val_accuracy: 0.6924
# Epoch 15/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6424 - accuracy: 0.7089 - val_loss: 0.7094 - val_accuracy: 0.6934
# Epoch 16/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.6310 - accuracy: 0.7152 - val_loss: 0.7094 - val_accuracy: 0.6904
# Epoch 17/50
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.6193 - accuracy: 0.7208 - val_loss: 0.7041 - val_accuracy: 0.6955
# Epoch 18/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.6090 - accuracy: 0.7235 - val_loss: 0.6929 - val_accuracy: 0.7021
# Epoch 19/50
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.5967 - accuracy: 0.7295 - val_loss: 0.7025 - val_accuracy: 0.7099
# Epoch 20/50
# 2000/2000 [==============================] - 33s 17ms/step - loss: 0.5886 - accuracy: 0.7311 - val_loss: 0.6973 - val_accuracy: 0.7053
# Epoch 21/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5767 - accuracy: 0.7396 - val_loss: 0.6934 - val_accuracy: 0.7036
# Epoch 22/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5657 - accuracy: 0.7436 - val_loss: 0.7010 - val_accuracy: 0.7013
# Epoch 23/50
# 2000/2000 [==============================] - 31s 16ms/step - loss: 0.5607 - accuracy: 0.7430 - val_loss: 0.6900 - val_accuracy: 0.7039
# Epoch 24/50
# 2000/2000 [==============================] - 31s 15ms/step - loss: 0.5531 - accuracy: 0.7478 - val_loss: 0.7012 - val_accuracy: 0.7011
# Best val accuracy: 0.7098749876022339
